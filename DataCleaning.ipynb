# %%
import pandas as pd
import numpy as np

# %%
june = "Resources/JC-201906-citibike-tripdata.csv"
july = "Resources/JC-201907-citibike-tripdata.csv"
august = "Resources/JC-201908-citibike-tripdata.csv"
june_pd = pd.read_csv(june, encoding="ISO-8859-1")
july_pd = pd.read_csv(july, encoding="ISO-8859-1")
august_pd = pd.read_csv(august, encoding="ISO-8859-1")

# %%
join_1 = june_pd.append(july_pd)

# %%
summer = join_1.append(august_pd)
len(summer)
# Out:
# 131887

# %%
summer.drop(summer.loc[summer['gender']==0].index, inplace=True)
summer.rename(columns={"tripduration": "tripduration(seconds)"})
summer
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               316  2019-06-01 00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  2019-06-01 00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  2019-06-01 00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  2019-06-01 00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  2019-06-01 00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...                       ...                       ...
# 48706           384  2019-08-31 23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  2019-08-31 23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  2019-08-31 23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  2019-08-31 23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  2019-08-31 23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# ...

# %%
new = summer["starttime"].str.split(" ", n = 1, expand = True) 
summer["startdate"] = new[0]
summer["starttime"] = new[1]
summer
# Out:
#        tripduration      starttime                  stoptime  \
# 0               316  00:05:55.7210  2019-06-01 00:11:11.9940
# 1               280  00:08:09.0920  2019-06-01 00:12:50.0730
# 4               139  00:13:31.8520  2019-06-01 00:15:51.7880
# 5               203  00:15:43.2590  2019-06-01 00:19:06.7450
# 6               671  00:19:41.5790  2019-06-01 00:30:52.6600
# ...             ...            ...                       ...
# 48706           384  23:40:45.2450  2019-08-31 23:47:09.8810
# 48707           633  23:45:55.6660  2019-08-31 23:56:29.5350
# 48708           324  23:50:27.9220  2019-08-31 23:55:52.8420
# 48709           126  23:52:21.9250  2019-08-31 23:54:28.5820
# 48710           690  23:56:55.1530  2019-09-01 00:08:25.2370
#
#        start station id start station name  start station latitude  \
# 0                  3187          Warren St               40.721124
# 1                  3185          City Hall               40.717733
# ...

# %%
end = summer["stoptime"].str.split(" ", n = 1, expand = True) 
summer["enddate"] = new[0]
summer["stoptime"] = new[1]
summer
# Out:
#        tripduration      starttime       stoptime  start station id  \
# 0               316  00:05:55.7210  00:05:55.7210              3187
# 1               280  00:08:09.0920  00:08:09.0920              3185
# 4               139  00:13:31.8520  00:13:31.8520              3207
# 5               203  00:15:43.2590  00:15:43.2590              3203
# 6               671  00:19:41.5790  00:19:41.5790              3202
# ...             ...            ...            ...               ...
# 48706           384  23:40:45.2450  23:40:45.2450              3639
# 48707           633  23:45:55.6660  23:45:55.6660              3186
# 48708           324  23:50:27.9220  23:50:27.9220              3276
# 48709           126  23:52:21.9250  23:52:21.9250              3211
# 48710           690  23:56:55.1530  23:56:55.1530              3185
#
#       start station name  start station latitude  start station longitude  \
# 0              Warren St               40.721124               -74.038051
# ...

# %%
group = summer.groupby('start station id').nunique()
len(group)
# Out:
# 52

# %%
export_csv = summer.to_csv (r'C:\Users\16314\Documents\Data Analytics BootCamp\20-Tableau\export.csv', index = None, header=True)
